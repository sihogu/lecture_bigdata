# %% [markdown]
# <a href="https://colab.research.google.com/github/sihogu/lecture_bigdata/blob/master/pandas_bigdata01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
exam_data = {'이름':['서준','우현','인아'],
             '수학':[90,80,70],
             '영어':[98,89,95],
             '음악':[85,95,100],
             '체육':[100,90,95]}

df = pd.DataFrame(exam_data,index=['1반','2반','3반'])
df

# %% [markdown]
# **인덱싱과 슬라이싱**

# %%
#데이터프레임의 행이나 열 접근(인덱싱)

df['이름']
df.이름   #열접근방식

df.loc['1반'] #행 이름으로 인덱싱, 슬라이싱할 시 마지막을 포함
df.iloc[0] #행 정수형 위치 인덱스 이름으로 인덱싱, 슬라이싱할 시 마지막은 제외

df.loc[['1반','2반','3반']] # 행 다수 인덱싱 [[]]
df[['이름','수학']] # 열 다수 인덱싱 [[]]


df.loc[:,'이름':'체육'] #loc 열 슬라이싱. 마지막을 포함. 앞에 : 를하나 붙인다!!
df.iloc[:,0:2] #iloc 열 슬라이싱. 마지막은 제외

df[0:2] #행 슬라이싱
df[0:3:2] #행 슬라이싱을 두칸씩 띄엄띄엄 하기
df[::-1] #행 슬라이싱 역순으로 하기
df['1반':'2반'] #행 슬라이싱, 인덱스명
df.loc['1반':'2반'] # 행 슬라이싱, 인덱스명
#행 슬라이싱은 .iloc나 .loc를 안붙여도 잘된다.

# %% [markdown]
# **원소 찾기**

# %%
df.loc['1반','수학'] #loc 원소 인덱싱 [행이름, 열이름] , type = numpy
df.iloc[0,1] #iloc 원소 인덱싱 [행 번호, 열 번호] , type = numpy
df.iloc[0][1]

df.iloc[0,[1,2]] #연속 원소 인덱싱(가로) [행 번호, [시작 열 번호, 끝 열 번호]], type = Series
df.iloc[[0,1],1] #연속 원소 인덱싱(세로) [[시작 행 번호, 끝 행 번호], 열 번호], type = Series

df.iloc[[0,1],[0,1]] #데이터프레임 인덱싱 [[행,행],[열,열]], type = DataFrame
df.loc[:,['음악','체육']]
# Out:
#       음악   체육
# 1반    85  100
# 2반    95   90
# 3반   100   95
# 특수반    0    0
# 1      0    0

# %% [markdown]
# **행과 열 추가 (한번 입력시 적용)**
#
# **행과 열 삭제 (입력만으로는 적용되지않음. 변수에 담기)**

# %%
df['국어'] = 80 #새로운 열과 값 추가
df.loc['4반'] = 0 #새로운 행과 값 추가

df.drop(1,axis = 0) #해당하는 행 이름 삭제, 완전 삭제 시키려면 데이터프레임 변수에 입력해야한다. 안보이게만하는 기능일뿐
df.drop(['특수반','4반']) #다수 행 삭제
df.drop('국어', axis = 1) #열 삭제, axis = 1 축을 1로 변경

df = df.drop(['특수반',1])

# %% [markdown]
# **원소 값 변경**

# %%
df.iloc[0,3] = 82 #행 0 열 3에 해당하는 원소 값 변경
df.loc['1반',['음악','체육']] = 50, 51 #여러 개의 원소 값 각각 변경
df.loc['1반',['음악','체육']] = 50 #여러 개의 원소 값 50 고정 변경

# %% [markdown]
# **기타 함수**

# %%
df.transpose() #전체 행과 열 위치 변경 (적용은 안됨)

df.set_index('이름') #열 이름 하나를 행 인덱스 맨 위로 두고, 해당 열의 값들을 행 인덱스 이름으로 부여.
#특정 열을 행 인덱스로 부여

df.reindex(['1반','2반','3반','4반']) #새로운 행 인덱스 명 한꺼번에 부여. 없는 행 인덱스 명이거나 없던 행일경우 NaN 값 부여.(fill_value=0)으로 NaN값이 아닌 0값 부여 가능..

df.reset_index() #행 인덱스를 정수형 위치 인덱스로 초기화하고, 기존 행 인덱스를 첫째 열로 이동.

df.rename(index={'1':'2반','2':'3반','3':'1반'},inplace=True)

df.sort_index() #행 인덱스 명 문자열 기준 내림차순으로 정렬한다. (ascending=False)는 오름차순 (ascending=True)는 내림차순이다.
# Out:
#     이름    수학    영어     음악    체육    국어
# 1반  인아  70.0  95.0  100.0  95.0  80.0
# 2반  서준  90.0  98.0   50.0  51.0  80.0
# 3반  우현  80.0  89.0   95.0  90.0  80.0
